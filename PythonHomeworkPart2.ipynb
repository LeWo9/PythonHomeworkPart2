# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("HR.csv")

# %%
df.head(100)
# Out:
#     satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                 0.38             0.53               2                   157
# 1                 0.80             0.86               5                   262
# 2                 0.11             0.88               7                   272
# 3                 0.72             0.87               5                   223
# 4                 0.37             0.52               2                   159
# ..                 ...              ...             ...                   ...
# 95                0.37             0.51               2                   155
# 96                0.10             0.77               6                   265
# 97                0.10             0.84               6                   279
# 98                0.11             0.97               6                   284
# 99                0.90             1.00               5                   221
#
# ...

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
df.corr()
# Out:
# <ipython-input-10-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.105021       -0.142970
# last_evaluation                  0.105021         1.000000        0.349333
# number_project                  -0.142970         0.349333        1.000000
# average_montly_hours            -0.020048         0.339742        0.417211
# time_spend_company              -0.100866         0.131591        0.196786
# Work_accident                    0.058697        -0.007104       -0.004741
# left                            -0.388375         0.006567        0.023787
# promotion_last_5years            0.025605        -0.008684       -0.006064
#
# ...

# %% [markdown]
# самые скоррелированные - average_montly_hours и number_project
# наименее скоррелированные - promotion_last_5years и average_montly_hours

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-11-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
df.groupby('department').size()
# Out:
# department
# IT             1227
# RandD           787
# accounting      767
# hr              739
# management      630
# marketing       858
# product_mng     902
# sales          4140
# support        2229
# technical      2720
# dtype: int64

# %%
plt.hist(df['salary'])
# Out:
# (array([7316.,    0.,    0.,    0.,    0., 6446.,    0.,    0.,    0.,
#         1237.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.displot(
  data=df,
  x="salary",
  hue="department",
  kind="hist"
)

# %%
df.groupby('salary').agg({'average_montly_hours': ['mean']})
# Out:
#        average_montly_hours
#                        mean
# salary
# high             199.867421
# low              200.996583
# medium           201.338349

# %% [markdown]
# Гипотеза, что сотрудники с высоким окладом проводят на работе больше времени не подтвердилась

# %%
df.groupby(['left'])['promotion_last_5years', 'satisfaction_level', 'number_project'].mean()
# Out:
# <ipython-input-17-a3f06df792dc>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['left'])['promotion_last_5years', 'satisfaction_level', 'number_project'].mean()
#       promotion_last_5years  satisfaction_level  number_project
# left
# 0                  0.026251            0.666810        3.786664
# 1                  0.005321            0.440098        3.855503

# %%
X, y = df[['satisfaction_level', 'time_spend_company', 'Work_accident', 'promotion_last_5years', 'last_evaluation', 'number_project', 'average_montly_hours']], df['left']

# %%
# Функции для разделения данных на данные для обучения и тестирования
from sklearn.model_selection import train_test_split

# %%
# Разделяем данные на данные для обучения и тестирования
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Импортируем модуль линейной регрессии
from sklearn. discriminant_analysis import LinearDiscriminantAnalysis as LDA

# %%
model = LDA()

# %%
model.fit(X_train, y_train)
# Out:
# LinearDiscriminantAnalysis()

# %%
# Оцениваем качество
from sklearn.metrics import accuracy_score

# %%
# Оцениваем качество на выборке для обучения
accuracy_score(y_train, model.predict(X_train))
# Out:
# 0.7613967830652555

# %%
# Оцениваем качество на выборке для тестирования
accuracy_score(y_test, model.predict(X_test))
# Out:
# 0.7583333333333333
